# %% [markdown]
# # Stock Market data prediction using Historical Data

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression,LogisticRegression
import pandas_datareader as web

# %% [markdown]
# # Training and Testing for Different Stock (TATA STEEL)

# %% [markdown]
# # Predict next day's close price (Experimental)

# %%
# data_num = pd.read_csv('djia.csv')
data_num = web.DataReader('KAJARIACER.NS', data_source='yahoo', start='2020-01-01', end='2021-01-14')
data_num.reset_index(level=0, inplace=True)
data_num.tail()
# Out:
#           Date        High         Low        Open       Close    Volume  \
# 255 2021-01-08  735.500000  721.000000  728.000000  726.799988  394185.0
# 256 2021-01-11  752.750000  730.450012  730.450012  750.049988  435389.0
# 257 2021-01-12  752.799988  738.099976  751.000000  741.400024  508522.0
# 258 2021-01-13  755.000000  733.049988  748.000000  751.349976  264788.0
# 259 2021-01-14  751.849976  735.150024  749.700012  743.450012  144937.0
#
#       Adj Close
# 255  726.799988
# 256  750.049988
# 257  741.400024
# 258  751.349976
# 259  743.450012

# %%
openP = data_num.tail(1)['Open']
closeP = data_num.tail(1)['Close']

# %%
data_num['NextOpen'] = 0
# data_num['NextClose'] = 0
data_num['NextHigh'] = 0
data_num['NextLow'] = 0

# %%
data_num.tail()
# Out:
#           Date        High         Low        Open       Close    Volume  \
# 255 2021-01-08  735.500000  721.000000  728.000000  726.799988  394185.0
# 256 2021-01-11  752.750000  730.450012  730.450012  750.049988  435389.0
# 257 2021-01-12  752.799988  738.099976  751.000000  741.400024  508522.0
# 258 2021-01-13  755.000000  733.049988  748.000000  751.349976  264788.0
# 259 2021-01-14  751.849976  735.150024  749.700012  743.450012  144937.0
#
#       Adj Close  NextOpen  NextHigh  NextLow
# 255  726.799988         0         0        0
# 256  750.049988         0         0        0
# 257  741.400024         0         0        0
# 258  751.349976         0         0        0
# 259  743.450012         0         0        0

# %%
for i in range(0, len(data_num) - 1):
    data_num.loc[i, 'NextOpen'] = data_num.loc[i+1, 'Open']   
#     data_num.loc[i, 'NextClose'] = data_num.loc[i+1, 'Close']
    data_num.loc[i, 'NextHigh'] = data_num.loc[i+1, 'High']
    data_num.loc[i, 'NextLow'] = data_num.loc[i+1, 'Low']

# %%
data_num
# Out:
#           Date        High         Low        Open       Close    Volume  \
# 0   2020-01-01  527.500000  522.349976  527.500000  525.549988   26939.0
# 1   2020-01-02  534.799988  524.000000  525.000000  533.000000  400151.0
# 2   2020-01-03  539.900024  528.000000  533.000000  536.799988  170159.0
# 3   2020-01-06  536.000000  522.900024  536.000000  526.049988  115874.0
# 4   2020-01-07  539.900024  527.400024  529.000000  530.349976  153110.0
# ..         ...         ...         ...         ...         ...       ...
# 255 2021-01-08  735.500000  721.000000  728.000000  726.799988  394185.0
# 256 2021-01-11  752.750000  730.450012  730.450012  750.049988  435389.0
# 257 2021-01-12  752.799988  738.099976  751.000000  741.400024  508522.0
# 258 2021-01-13  755.000000  733.049988  748.000000  751.349976  264788.0
# 259 2021-01-14  751.849976  735.150024  749.700012  743.450012  144937.0
#
#       Adj Close    NextOpen    NextHigh     NextLow
# 0    522.581909  525.000000  534.799988  524.000000
# 1    529.989807  533.000000  539.900024  528.000000
# 2    533.768372  536.000000  536.000000  522.900024
# 3    523.079041  529.000000  539.900024  527.400024
# 4    527.354797  525.000000  558.000000  520.400024
# ..          ...         ...         ...         ...
# 255  726.799988  730.450012  752.750000  730.450012
# 256  750.049988  751.000000  752.799988  738.099976
# 257  741.400024  748.000000  755.000000  733.049988
# 258  751.349976  749.700012  751.849976  735.150024
# 259  743.450012    0.000000    0.000000    0.000000
#
# [260 rows x 10 columns]

# %%
data_num = data_num[:-1]

# %%
data_num
# Out:
#           Date        High         Low        Open       Close    Volume  \
# 0   2020-01-01  527.500000  522.349976  527.500000  525.549988   26939.0
# 1   2020-01-02  534.799988  524.000000  525.000000  533.000000  400151.0
# 2   2020-01-03  539.900024  528.000000  533.000000  536.799988  170159.0
# 3   2020-01-06  536.000000  522.900024  536.000000  526.049988  115874.0
# 4   2020-01-07  539.900024  527.400024  529.000000  530.349976  153110.0
# ..         ...         ...         ...         ...         ...       ...
# 254 2021-01-07  727.900024  711.000000  714.099976  723.549988  526207.0
# 255 2021-01-08  735.500000  721.000000  728.000000  726.799988  394185.0
# 256 2021-01-11  752.750000  730.450012  730.450012  750.049988  435389.0
# 257 2021-01-12  752.799988  738.099976  751.000000  741.400024  508522.0
# 258 2021-01-13  755.000000  733.049988  748.000000  751.349976  264788.0
#
#       Adj Close    NextOpen    NextHigh     NextLow
# 0    522.581909  525.000000  534.799988  524.000000
# 1    529.989807  533.000000  539.900024  528.000000
# 2    533.768372  536.000000  536.000000  522.900024
# 3    523.079041  529.000000  539.900024  527.400024
# 4    527.354797  525.000000  558.000000  520.400024
# ..          ...         ...         ...         ...
# 254  723.549988  728.000000  735.500000  721.000000
# 255  726.799988  730.450012  752.750000  730.450012
# 256  750.049988  751.000000  752.799988  738.099976
# 257  741.400024  748.000000  755.000000  733.049988
# 258  751.349976  749.700012  751.849976  735.150024
#
# [259 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_num.drop(['NextHigh','Date','High','Low','Adj Close','Volume','NextLow'],axis=1)
# X = data_num.drop(['Close','Adj Close'],axis=1)

y = data_num[['NextHigh','NextLow']]
X_train, X_test, y_train, y_test = train_test_split(X,y)
model = LinearRegression()
model.fit(X_train, y_train)
mscore = model.score(X_test,y_test)
mscore
# Out:
# 0.9942364636699631

# %%
y_pred = model.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.plot(y_test,y_pred,marker='o',linestyle='',label="Predicted")
plt.plot(y_test,y_test, label="Original")

plt.legend(loc='best')
plt.grid()
plt.show()

# %%
X_test.tail()
# Out:
#            Open       Close    NextOpen
# 208  565.000000  569.400024  567.000000
# 92   302.799988  310.549988  312.899994
# 129  389.000000  388.899994  391.850006
# 99   318.149994  342.000000  354.000000
# 211  574.000000  574.900024  574.299988

# %%
nextOpenP = 743.45000
pred = model.predict([[openP,closeP,nextOpenP]])
# Out:
# D:\anaconda\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
pred
# Out:
# array([[753.03510077, 734.25506133]])

# %%
diff = (nextOpenP * (100-(mscore*100))/100)
print("variance = ",diff)
ph = (pred[0][0]- diff) - nextOpenP
lp = nextOpenP   -  (pred[0][1] + diff )
if ph > lp:
    profit = ph
    print("Profit/Stock  = ",ph)
    print("Buy at :",nextOpenP,'and sell at :',(pred[0][0]) - diff )
else:
    profit = lp
    print("Profit/Stock  = ",lp)
    print("sell at :",nextOpenP,'and buy at :',(pred[0][1]) + diff )
# Out:
# variance =  3
# Profit/Stock  =  6.5851007732510425
# Buy at : 743.45 and sell at : 750.0351007732511

# %%
stock  = int(input("How Many Stocks?\n"))
print("Your Profit is = ",profit * stock)
# Out:
# How Many Stocks?
# 134
# Your Profit is =  882.4035036156397

# %%
134*9
# Out:
# 1206
