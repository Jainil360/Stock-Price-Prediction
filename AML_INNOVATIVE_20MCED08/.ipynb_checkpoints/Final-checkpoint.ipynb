# %% [markdown]
# # Stock Market data prediction using Historical Data

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression,LogisticRegression
import pandas_datareader as web

# %% [markdown]
# # Training and Testing for Different Stock (TATA STEEL)

# %% [markdown]
# # Predict next day's close price (Experimental)

# %%
# data_num = pd.read_csv('djia.csv')
data_num = web.DataReader('TATAMOTORS.NS', data_source='yahoo', start='2020-01-01', end='2021-01-15')
data_num.reset_index(level=0, inplace=True)
data_num.tail()
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 256 2021-01-11  225.399994  199.649994  199.899994  220.649994  182483100.0
# 257 2021-01-12  252.399994  224.100006  227.000000  237.800003  390577839.0
# 258 2021-01-13  248.800003  238.399994  242.899994  242.600006  164649387.0
# 259 2021-01-14  249.800003  238.600006  242.850006  245.100006   86819519.0
# 260 2021-01-15  264.649994  242.600006  246.000000  260.299988  250038029.0
#
#       Adj Close
# 256  220.649994
# 257  237.800003
# 258  242.600006
# 259  245.100006
# 260  260.299988

# %%
openP = data_num.tail(1)['Open']
closeP = data_num.tail(1)['Close']

# %%
data_num['NextOpen'] = 0
# data_num['NextClose'] = 0
data_num['NextHigh'] = 0
data_num['NextLow'] = 0

# %%
data_num.tail()
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 256 2021-01-11  225.399994  199.649994  199.899994  220.649994  182483100.0
# 257 2021-01-12  252.399994  224.100006  227.000000  237.800003  390577839.0
# 258 2021-01-13  248.800003  238.399994  242.899994  242.600006  164649387.0
# 259 2021-01-14  249.800003  238.600006  242.850006  245.100006   86819519.0
# 260 2021-01-15  264.649994  242.600006  246.000000  260.299988  250038029.0
#
#       Adj Close  NextOpen  NextHigh  NextLow
# 256  220.649994         0         0        0
# 257  237.800003         0         0        0
# 258  242.600006         0         0        0
# 259  245.100006         0         0        0
# 260  260.299988         0         0        0

# %%
for i in range(0, len(data_num) - 1):
    data_num.loc[i, 'NextOpen'] = data_num.loc[i+1, 'Open']   
#     data_num.loc[i, 'NextClose'] = data_num.loc[i+1, 'Close']
    data_num.loc[i, 'NextHigh'] = data_num.loc[i+1, 'High']
    data_num.loc[i, 'NextLow'] = data_num.loc[i+1, 'Low']

# %%
data_num
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 0   2020-01-01  186.699997  183.600006  185.149994  184.449997   25968357.0
# 1   2020-01-02  194.699997  184.600006  185.000000  193.750000   57289863.0
# 2   2020-01-03  195.649994  189.250000  192.899994  191.100006   47572728.0
# 3   2020-01-06  191.000000  185.050003  191.000000  185.649994   28621212.0
# 4   2020-01-07  189.399994  182.300003  187.000000  184.699997   34995035.0
# ..         ...         ...         ...         ...         ...          ...
# 256 2021-01-11  225.399994  199.649994  199.899994  220.649994  182483100.0
# 257 2021-01-12  252.399994  224.100006  227.000000  237.800003  390577839.0
# 258 2021-01-13  248.800003  238.399994  242.899994  242.600006  164649387.0
# 259 2021-01-14  249.800003  238.600006  242.850006  245.100006   86819519.0
# 260 2021-01-15  264.649994  242.600006  246.000000  260.299988  250038029.0
#
#       Adj Close    NextOpen    NextHigh     NextLow
# 0    184.449997  185.000000  194.699997  184.600006
# 1    193.750000  192.899994  195.649994  189.250000
# 2    191.100006  191.000000  191.000000  185.050003
# 3    185.649994  187.000000  189.399994  182.300003
# 4    184.699997  180.199997  184.199997  180.199997
# ..          ...         ...         ...         ...
# 256  220.649994  227.000000  252.399994  224.100006
# 257  237.800003  242.899994  248.800003  238.399994
# 258  242.600006  242.850006  249.800003  238.600006
# 259  245.100006  246.000000  264.649994  242.600006
# 260  260.299988    0.000000    0.000000    0.000000
#
# [261 rows x 10 columns]

# %%
data_num = data_num[:-1]

# %%
data_num
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 0   2020-01-01  186.699997  183.600006  185.149994  184.449997   25968357.0
# 1   2020-01-02  194.699997  184.600006  185.000000  193.750000   57289863.0
# 2   2020-01-03  195.649994  189.250000  192.899994  191.100006   47572728.0
# 3   2020-01-06  191.000000  185.050003  191.000000  185.649994   28621212.0
# 4   2020-01-07  189.399994  182.300003  187.000000  184.699997   34995035.0
# ..         ...         ...         ...         ...         ...          ...
# 255 2021-01-08  201.500000  197.100006  198.750000  198.149994   53991568.0
# 256 2021-01-11  225.399994  199.649994  199.899994  220.649994  182483100.0
# 257 2021-01-12  252.399994  224.100006  227.000000  237.800003  390577839.0
# 258 2021-01-13  248.800003  238.399994  242.899994  242.600006  164649387.0
# 259 2021-01-14  249.800003  238.600006  242.850006  245.100006   86819519.0
#
#       Adj Close    NextOpen    NextHigh     NextLow
# 0    184.449997  185.000000  194.699997  184.600006
# 1    193.750000  192.899994  195.649994  189.250000
# 2    191.100006  191.000000  191.000000  185.050003
# 3    185.649994  187.000000  189.399994  182.300003
# 4    184.699997  180.199997  184.199997  180.199997
# ..          ...         ...         ...         ...
# 255  198.149994  199.899994  225.399994  199.649994
# 256  220.649994  227.000000  252.399994  224.100006
# 257  237.800003  242.899994  248.800003  238.399994
# 258  242.600006  242.850006  249.800003  238.600006
# 259  245.100006  246.000000  264.649994  242.600006
#
# [260 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_num.drop(['NextHigh','Date','High','Low','Adj Close','Volume','NextLow'],axis=1)
# X = data_num.drop(['Close','Adj Close'],axis=1)

y = data_num[['NextHigh','NextLow']]
X_train, X_test, y_train, y_test = train_test_split(X,y)
model = LinearRegression()
model.fit(X_train, y_train)
mscore = model.score(X_test,y_test)
mscore
# Out:
# 0.9950362680151423

# %%
y_pred = model.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.plot(y_test,y_pred,marker='o',linestyle='',label="Predicted")
plt.plot(y_test,y_test, label="Original")

plt.legend(loc='best')
plt.grid()
plt.show()

# %%
X_test.tail()
# Out:
#            Open       Close    NextOpen
# 83    81.550003   83.199997   82.900002
# 0    185.149994  184.449997  185.000000
# 19   183.899994  176.100006  178.800003
# 34   168.000000  161.600006  162.850006
# 157  127.000000  125.150002  123.449997

# %%
nextOpenP = 261.65000
pred = model.predict([[openP,closeP,nextOpenP]])
# Out:
# D:\anaconda\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
pred
# Out:
# array([[267.06435439, 257.57365256]])

# %%
diff = (nextOpenP * (100-(mscore*100))/100)
print("variance = ",diff)
ph = (pred[0][0]- diff) - nextOpenP
lp = nextOpenP   -  (pred[0][1] + diff )
if ph > lp:
    profit = ph
    print("Profit/Stock  = ",ph)
    print("Buy at :",nextOpenP,'and sell at :',(pred[0][0]) - diff )
else:
    profit = lp
    print("Profit/Stock  = ",lp)
    print("sell at :",nextOpenP,'and buy at :',(pred[0][1]) + diff )
# Out:
# variance =  1.2987604738380176
# Profit/Stock  =  4.1155939124265615
# Buy at : 261.65 and sell at : 265.76559391242654

# %%
stock  = int(input("How Many Stocks?\n"))
print("Your Profit is = ",profit * stock)
# Out:
# How Many Stocks?
# 383
# Your Profit is =  1576.2724684593732

# %%
100000/261
# Out:
# 383.1417624521073
