# %% [markdown]
# # Stock Market data prediction using Historical Data

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression,LogisticRegression
import pandas_datareader as web
model = LinearRegression()

# %% [markdown]
# # Training and Testing for Different Stock (TATA STEEL)

# %% [markdown]
# # Predict next day's close price (Experimental)

# %%
# data_num = pd.read_csv('djia.csv')
data_num = web.DataReader('TATASTEEL.NS', data_source='yahoo', start='2020-01-01', end='2021-01-12')
data_num.reset_index(level=0, inplace=True)
data_num.tail()
# Out:
#           Date        High         Low   Open       Close      Volume  \
# 253 2021-01-06  696.650024  675.000000  684.0  683.799988  19610522.0
# 254 2021-01-07  731.500000  691.700012  693.0  722.799988  38232194.0
# 255 2021-01-08  727.250000  703.099976  727.0  713.150024  19329313.0
# 256 2021-01-11  712.000000  688.200012  712.0  695.650024  17024509.0
# 257 2021-01-12  724.500000  691.099976  695.0  694.900024  24525484.0
#
#       Adj Close
# 253  683.799988
# 254  722.799988
# 255  713.150024
# 256  695.650024
# 257  694.900024

# %%
data_num['NextOpen'] = 0
# data_num['NextClose'] = 0
data_num['NextHigh'] = 0

# %%
data_num.tail()
# Out:
#           Date        High         Low   Open       Close      Volume  \
# 253 2021-01-06  696.650024  675.000000  684.0  683.799988  19610522.0
# 254 2021-01-07  731.500000  691.700012  693.0  722.799988  38232194.0
# 255 2021-01-08  727.250000  703.099976  727.0  713.150024  19329313.0
# 256 2021-01-11  712.000000  688.200012  712.0  695.650024  17024509.0
# 257 2021-01-12  724.500000  691.099976  695.0  694.900024  24525484.0
#
#       Adj Close  NextOpen  NextHigh
# 253  683.799988         0         0
# 254  722.799988         0         0
# 255  713.150024         0         0
# 256  695.650024         0         0
# 257  694.900024         0         0

# %%
for i in range(0, len(data_num) - 1):
    data_num.loc[i, 'NextOpen'] = data_num.loc[i+1, 'Open']   
#     data_num.loc[i, 'NextClose'] = data_num.loc[i+1, 'Close']
    data_num.loc[i, 'NextHigh'] = data_num.loc[i+1, 'High']

# %%
data_num
# Out:
#           Date        High         Low   Open       Close      Volume  \
# 0   2020-01-01  476.500000  464.799988  473.0  467.750000  12100530.0
# 1   2020-01-02  487.799988  472.000000  472.0  484.850006  21674961.0
# 2   2020-01-03  486.200012  479.450012  483.0  483.700012  12956863.0
# 3   2020-01-06  480.000000  470.549988  480.0  473.250000   9601608.0
# 4   2020-01-07  484.600006  473.549988  475.5  476.100006  13195788.0
# ..         ...         ...         ...    ...         ...         ...
# 253 2021-01-06  696.650024  675.000000  684.0  683.799988  19610522.0
# 254 2021-01-07  731.500000  691.700012  693.0  722.799988  38232194.0
# 255 2021-01-08  727.250000  703.099976  727.0  713.150024  19329313.0
# 256 2021-01-11  712.000000  688.200012  712.0  695.650024  17024509.0
# 257 2021-01-12  724.500000  691.099976  695.0  694.900024  24525484.0
#
#       Adj Close    NextOpen    NextHigh
# 0    455.932159  472.000000  487.799988
# 1    472.600128  483.000000  486.200012
# 2    471.479187  480.000000  480.000000
# 3    461.293213  475.500000  484.600006
# 4    464.071198  471.649994  478.149994
# ..          ...         ...         ...
# 253  683.799988  693.000000  731.500000
# 254  722.799988  727.000000  727.250000
# 255  713.150024  712.000000  712.000000
# 256  695.650024  695.000000  724.500000
# 257  694.900024    0.000000    0.000000
#
# [258 rows x 9 columns]

# %%
data_num = data_num[:-1]

# %%
data_num
# Out:
#           Date        High         Low   Open       Close      Volume  \
# 0   2020-01-01  476.500000  464.799988  473.0  467.750000  12100530.0
# 1   2020-01-02  487.799988  472.000000  472.0  484.850006  21674961.0
# 2   2020-01-03  486.200012  479.450012  483.0  483.700012  12956863.0
# 3   2020-01-06  480.000000  470.549988  480.0  473.250000   9601608.0
# 4   2020-01-07  484.600006  473.549988  475.5  476.100006  13195788.0
# ..         ...         ...         ...    ...         ...         ...
# 252 2021-01-05  693.849976  675.099976  687.0  680.549988  21545254.0
# 253 2021-01-06  696.650024  675.000000  684.0  683.799988  19610522.0
# 254 2021-01-07  731.500000  691.700012  693.0  722.799988  38232194.0
# 255 2021-01-08  727.250000  703.099976  727.0  713.150024  19329313.0
# 256 2021-01-11  712.000000  688.200012  712.0  695.650024  17024509.0
#
#       Adj Close    NextOpen    NextHigh
# 0    455.932159  472.000000  487.799988
# 1    472.600128  483.000000  486.200012
# 2    471.479187  480.000000  480.000000
# 3    461.293213  475.500000  484.600006
# 4    464.071198  471.649994  478.149994
# ..          ...         ...         ...
# 252  680.549988  684.000000  696.650024
# 253  683.799988  693.000000  731.500000
# 254  722.799988  727.000000  727.250000
# 255  713.150024  712.000000  712.000000
# 256  695.650024  695.000000  724.500000
#
# [257 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_num.drop(['NextHigh','Date','High','Low','Adj Close','Volume'],axis=1)
# X = data_num.drop(['Close','Adj Close'],axis=1)

y = data_num['NextHigh']
X_train, X_test, y_train, y_test = train_test_split(X,y)

model.fit(X_train, y_train)
model.score(X_test,y_test)
# Out:
# 0.9877666443002007

# %%
y_pred = model.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.plot(y_test,y_pred,marker='o',linestyle='',label="Predicted")
plt.plot(y_test,y_test, label="Original")

plt.legend(loc='best')
plt.grid()
plt.show()

# %%
X_test.tail()
# Out:
#            Open       Close    NextOpen
# 26   478.000000  477.600006  475.700012
# 185  359.950012  361.000000  365.000000
# 207  399.450012  401.399994  402.700012
# 103  316.899994  319.950012  325.799988
# 241  638.250000  631.250000  624.000000

# %%
predicted_close = model.predict([[712.0,695.650024,695.000000]]) #12 jan

# %%
predicted_close
# Out:
# array([707.1137804])

# %%
predicted_close = model.predict([[695.0,694.900024,701.45]]) #13 jan

# %%
predicted_close[0]
# Out:
# 712.3393815000047

# %%
stocks = int(input())
print(abs(stocks * (701.45 - predicted_close[0])))
# Out:
# 200
# 2177.876300000935
